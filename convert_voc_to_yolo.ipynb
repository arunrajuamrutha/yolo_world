# %%
import os
import xml.etree.ElementTree as ET

def convert_voc_to_yolo(xml_path, image_path, class_names):
  """
  Converts a Pascal VOC XML annotation file to YOLOv8 text format.

  Args:
    xml_path: Path to the Pascal VOC XML annotation file.
    image_path: Path to the corresponding image file.
    class_names: List of class names for the dataset.

  Returns:
    A string containing the YOLOv8 text format for the annotation.
  """

  # Open the XML file (considering potential permission issues)
  try:
    with open(xml_path) as f:
      xml_data = f.read()
  except PermissionError:
    print(f"Error: Permission denied accessing {xml_path}. Check file permissions.")
    return None

  tree = ET.fromstring(xml_data)

  # Extract image dimensions (assuming width/height are available in the XML)
  width = int(tree.find('size').find('width').text)
  height = int(tree.find('size').find('height').text)

  # Extract objects from the XML (using a dictionary)
  objects = []
  for obj in tree.findall('object'):
    name = obj.find('name').text
    bndbox = obj.find('bndbox')
    xmin = int(bndbox.find('xmin').text)
    ymin = int(bndbox.find('ymin').text)
    xmax = int(bndbox.find('xmax').text)
    ymax = int(bndbox.find('ymax').text)
    objects.append({
      "name": name,
      "xmin": xmin,
      "ymin": ymin,
      "xmax": xmax,
      "ymax": ymax
    })

  # Generate YOLOv8 text format
  yolo_text = ""
  for object in objects:
    class_id = class_names.index(object["name"])
    center_x = (object["xmin"] + object["xmax"]) / 2.0 / width
    center_y = (object["ymin"] + object["ymax"]) / 2.0 / height
    width = (object["xmax"] - object["xmin"]) / width
    height = (object["ymax"] - object["ymin"]) / height
    yolo_text += f"{class_id} {center_x} {center_y} {width} {height}\n"

  return yolo_text

# Define paths and class names
xml_dir = "C:\\Users\\hp\\Desktop\\machine-test\\datasets\\labels"  # Replace with your directory
image_dir = "C:\\Users\\hp\\Desktop\\machine-test\\datasets\\images"  # Replace with your directory (assuming images are here)
class_names=["person",
"hard-hat",
"gloves",
"mask",
"glasses",
"boots",
"vest",
"ppe-suit",
"ear-protector",
"safety-harness"] # Replace with your class names

# Loop through each XML file
for filename in os.listdir(xml_dir):
  if filename.endswith(".xml"):
    xml_path = os.path.join(xml_dir, filename)
    image_path = os.path.join(image_dir, filename.replace(".xml", ".jpg"))  # Assuming jpg format

    # Convert the XML to YOLOv8 format
    yolo_text = convert_voc_to_yolo(xml_path, image_path, class_names)

    if yolo_text is not None:  # Check if conversion successful
      # Save the YOLOv8 text to a file with the same name as the image
      with open(os.path.join(image_dir, filename.replace(".xml", ".txt")), "w") as f:
        f.write(yolo_text)
      print(f"Converted {filename} to YOLOv8 format!")

print("Finished converting Pascal VOC XML annotations!")
# Out:
# Converted -1477-_png_jpg.rf.bac8d06edca64da17ced23797d0e2339.xml to YOLOv8 format!
# Converted -1532-_png_jpg.rf.08a5b6985f24bfe7efefdb45c04469c2.xml to YOLOv8 format!
# Converted -1571-_png_jpg.rf.ccf919d5ea025ddc24cf0a707b331249.xml to YOLOv8 format!
# Converted -1579-_png_jpg.rf.c8f91ec3791bf03ccf9eca6c29f62aec.xml to YOLOv8 format!
# Converted -1597-_png_jpg.rf.3bd5df66feaa51e0d65197b4acaf356f.xml to YOLOv8 format!
# Converted -1817-_png_jpg.rf.0c0c9d7ee4b875c6ad49937fc72182f6.xml to YOLOv8 format!
# Converted -1832-_png_jpg.rf.d56cb4edba4c059bdfa7f2c581d26a19.xml to YOLOv8 format!
# Converted -184-_png_jpg.rf.b02963998a79b9ad5079f57b65130bc2.xml to YOLOv8 format!
# Converted -1943-_png_jpg.rf.fe8693f39c8d2c4be6615a63edd3550d.xml to YOLOv8 format!
# Converted -2082-_png_jpg.rf.7b89e77b67643cd28c0ce52ed7e588e3.xml to YOLOv8 format!
# Converted -2091-_png_jpg.rf.24a38225fa17a89f450e6fcf90584bb5.xml to YOLOv8 format!
# Converted -2168-_png_jpg.rf.cd5ce7cad7216bda1d5a2e90d9ccdd4e.xml to YOLOv8 format!
# Converted -2180-_png_jpg.rf.9d63bb305e7747d22fe9a196dcc5ce13.xml to YOLOv8 format!
# Converted -2293-_png_jpg.rf.b1d581d625ae74bb60b5d56e7b562654.xml to YOLOv8 format!
# Converted -2338-_png_jpg.rf.e79ac380146af51e53738fd6184e1808.xml to YOLOv8 format!
# Converted -2390-_png_jpg.rf.fa4cf091a0bc051c044e2505719d3971.xml to YOLOv8 format!
# Converted -2391-_png_jpg.rf.8781d03c5c7efeeb7fdaeb65e1dd0fc7.xml to YOLOv8 format!
# Converted -2398-_png_jpg.rf.bcec23ae95199cde62866097de49e92c.xml to YOLOv8 format!
# Converted -2435-_png_jpg.rf.d88968da6353df51746244bb3619cc5a.xml to YOLOv8 format!
# Converted -4100-_png_jpg.rf.aebfe87c2b4f556f03d14fc3cc6facf7.xml to YOLOv8 format!
# Converted -4216-_png_jpg.rf.881e17f72716e3cbdaa9d20cf9558142.xml to YOLOv8 format!
# Converted -4379-_png_jpg.rf.03c410bbf91f791a4bade1f8673fa79c.xml to YOLOv8 format!
# Converted 001003.xml to YOLOv8 format!
# Converted 001005.xml to YOLOv8 format!
# Converted 001029.xml to YOLOv8 format!
# Converted 001037.xml to YOLOv8 format!
# Converted 001038.xml to YOLOv8 format!
# Converted 001042.xml to YOLOv8 format!
# Converted 001045.xml to YOLOv8 format!
# Converted 001054.xml to YOLOv8 format!
# Converted 001056_jpg.rf.fb5d9fbc2ccfa43ca89d84be6d2a98ea.xml to YOLOv8 format!
# Converted 001059.xml to YOLOv8 format!
# Converted 001060.xml to YOLOv8 format!
# Converted 001062.xml to YOLOv8 format!
# Converted 001071.xml to YOLOv8 format!
# Converted 001073.xml to YOLOv8 format!
# Converted 001080.xml to YOLOv8 format!
# Converted 001082.xml to YOLOv8 format!
# Converted 001083.xml to YOLOv8 format!
# Converted 001085.xml to YOLOv8 format!
# Converted 001086.xml to YOLOv8 format!
# Converted 001092.xml to YOLOv8 format!
# Converted 001093.xml to YOLOv8 format!
# Converted 001096.xml to YOLOv8 format!
# Converted 001107_jpg.rf.ddc4b21edf46aaa9518dfe33a381ff29.xml to YOLOv8 format!
# Converted 001109.xml to YOLOv8 format!
# Converted 001111.xml to YOLOv8 format!
# Converted 001124.xml to YOLOv8 format!
# Converted 001129.xml to YOLOv8 format!
# Converted 001142.xml to YOLOv8 format!
# Converted 001143.xml to YOLOv8 format!
# Converted 001146.xml to YOLOv8 format!
# Converted 001147.xml to YOLOv8 format!
# Converted 001152.xml to YOLOv8 format!
# Converted 001155.xml to YOLOv8 format!
# Converted 001157.xml to YOLOv8 format!
# Converted 001158.xml to YOLOv8 format!
# Converted 001164.xml to YOLOv8 format!
# Converted 001173.xml to YOLOv8 format!
# Converted 001175.xml to YOLOv8 format!
# Converted 001177.xml to YOLOv8 format!
# Converted 001179.xml to YOLOv8 format!
# Converted 001180.xml to YOLOv8 format!
# Converted 001183.xml to YOLOv8 format!
# Converted 001184.xml to YOLOv8 format!
# Converted 001185.xml to YOLOv8 format!
# Converted 001186.xml to YOLOv8 format!
# Converted 001187.xml to YOLOv8 format!
# Converted 001188.xml to YOLOv8 format!
# Converted 001190.xml to YOLOv8 format!
# Converted 001191.xml to YOLOv8 format!
# Converted 001196.xml to YOLOv8 format!
# Converted 001198.xml to YOLOv8 format!
# Converted 001199.xml to YOLOv8 format!
# Converted 001201.xml to YOLOv8 format!
# Converted 001202.xml to YOLOv8 format!
# Converted 001205.xml to YOLOv8 format!
# Converted 001209.xml to YOLOv8 format!
# Converted 001213.xml to YOLOv8 format!
# Converted 001214_jpg.rf.1341753c952df6e0889b1f781af22c77.xml to YOLOv8 format!
# Converted 001216_jpg.rf.c7de195db643cb4d72f58f262b39b050.xml to YOLOv8 format!
# Converted 001221.xml to YOLOv8 format!
# Converted 001222.xml to YOLOv8 format!
# Converted 001223.xml to YOLOv8 format!
# Converted 001224.xml to YOLOv8 format!
# Converted 001225.xml to YOLOv8 format!
# Converted 001229.xml to YOLOv8 format!
# Converted 001231.xml to YOLOv8 format!
# Converted 001232.xml to YOLOv8 format!
# Converted 001236.xml to YOLOv8 format!
# Converted 001242.xml to YOLOv8 format!
# Converted 001246_jpg.rf.05724a1c67f05c4fbd6fb3d872bc98b4.xml to YOLOv8 format!
# Converted 001250.xml to YOLOv8 format!
# Converted 001257.xml to YOLOv8 format!
# Converted 001265.xml to YOLOv8 format!
# Converted 001268.xml to YOLOv8 format!
# Converted 001271.xml to YOLOv8 format!
# Converted 001280.xml to YOLOv8 format!
# Converted 001282.xml to YOLOv8 format!
# Converted 001284.xml to YOLOv8 format!
# Converted 001291.xml to YOLOv8 format!
# Converted 001295.xml to YOLOv8 format!
# Converted 001297.xml to YOLOv8 format!
# Converted 001302.xml to YOLOv8 format!
# Converted 001302_jpg.rf.6e51fb4e9255ceda9bca16f35d4ae32b.xml to YOLOv8 format!
# Converted 001303.xml to YOLOv8 format!
# Converted 001305.xml to YOLOv8 format!
# Converted 001308.xml to YOLOv8 format!
# Converted 001318.xml to YOLOv8 format!
# Converted 001320.xml to YOLOv8 format!
# Converted 001321.xml to YOLOv8 format!
# Converted 001323.xml to YOLOv8 format!
# Converted 001324.xml to YOLOv8 format!
# Converted 001325.xml to YOLOv8 format!
# Converted 001326.xml to YOLOv8 format!
# Converted 001330.xml to YOLOv8 format!
# Converted 001331.xml to YOLOv8 format!
# Converted 001332.xml to YOLOv8 format!
# Converted 001333_jpg.rf.25550b8186ab6e741765efbb21e9e59e.xml to YOLOv8 format!
# Converted 001338.xml to YOLOv8 format!
# Converted 001339.xml to YOLOv8 format!
# Converted 001341.xml to YOLOv8 format!
# Converted 001344_jpg.rf.1c7c5ed37e407155e2d7cf0216f893ed.xml to YOLOv8 format!
# Converted 001345.xml to YOLOv8 format!
# Converted 001347.xml to YOLOv8 format!
# Converted 001353_jpg.rf.c0abf8e966961dd3c902dce35a401240.xml to YOLOv8 format!
# Converted 001358.xml to YOLOv8 format!
# Converted 001360.xml to YOLOv8 format!
# Converted 001363.xml to YOLOv8 format!
# Converted 001365.xml to YOLOv8 format!
# Converted 001367.xml to YOLOv8 format!
# Converted 001373.xml to YOLOv8 format!
# Converted 001376.xml to YOLOv8 format!
# Converted 001381.xml to YOLOv8 format!
# Converted 001388.xml to YOLOv8 format!
# Converted 001391.xml to YOLOv8 format!
# Converted 001392.xml to YOLOv8 format!
# Converted 001393.xml to YOLOv8 format!
# Converted 001395.xml to YOLOv8 format!
# Converted 001397.xml to YOLOv8 format!
# Converted 001406.xml to YOLOv8 format!
# Converted 001411.xml to YOLOv8 format!
# Converted 001412.xml to YOLOv8 format!
# Converted 001417.xml to YOLOv8 format!
# Converted 001418.xml to YOLOv8 format!
# Converted 001426.xml to YOLOv8 format!
# Converted 001436.xml to YOLOv8 format!
# Converted 001438.xml to YOLOv8 format!
# Converted 001442.xml to YOLOv8 format!
# Converted 001448.xml to YOLOv8 format!
# Converted 001451.xml to YOLOv8 format!
# Converted 001453.xml to YOLOv8 format!
# Converted 001454.xml to YOLOv8 format!
# Converted 001455.xml to YOLOv8 format!
# Converted 001474.xml to YOLOv8 format!
# Converted 001476.xml to YOLOv8 format!
# Converted 001479.xml to YOLOv8 format!
# Converted 001486.xml to YOLOv8 format!
# Converted 001487.xml to YOLOv8 format!
# Converted 001501.xml to YOLOv8 format!
# Converted 001502.xml to YOLOv8 format!
# Converted 001503.xml to YOLOv8 format!
# Converted 001509.xml to YOLOv8 format!
# Converted 001514.xml to YOLOv8 format!
# Converted 001516.xml to YOLOv8 format!
# Converted 001531.xml to YOLOv8 format!
# Converted 001532.xml to YOLOv8 format!
# Converted 001535.xml to YOLOv8 format!
# Converted 001541.xml to YOLOv8 format!
# Converted 001544.xml to YOLOv8 format!
# Converted 001545.xml to YOLOv8 format!
# Converted 001546.xml to YOLOv8 format!
# Converted 001547.xml to YOLOv8 format!
# Converted 001551.xml to YOLOv8 format!
# Converted 001553.xml to YOLOv8 format!
# Converted 001561.xml to YOLOv8 format!
# Converted 001568.xml to YOLOv8 format!
# Converted 001580.xml to YOLOv8 format!
# Converted 001589.xml to YOLOv8 format!
# Converted 001597.xml to YOLOv8 format!
# Converted 001604.xml to YOLOv8 format!
# Converted 001611.xml to YOLOv8 format!
# Converted 001618.xml to YOLOv8 format!
# Converted 001619.xml to YOLOv8 format!
# Converted 001624.xml to YOLOv8 format!
# Converted 001627.xml to YOLOv8 format!
# Converted 001628.xml to YOLOv8 format!
# Converted 001631.xml to YOLOv8 format!
# Converted 001634.xml to YOLOv8 format!
# Converted 001637.xml to YOLOv8 format!
# Converted 001642.xml to YOLOv8 format!
# Converted 001645.xml to YOLOv8 format!
# Converted 001646.xml to YOLOv8 format!
# Converted 001647.xml to YOLOv8 format!
# Converted 001649.xml to YOLOv8 format!
# Converted 001657.xml to YOLOv8 format!
# Converted 001659.xml to YOLOv8 format!
# Converted 001661.xml to YOLOv8 format!
# Converted 001664.xml to YOLOv8 format!
# Converted 001668.xml to YOLOv8 format!
# Converted 001669.xml to YOLOv8 format!
# Converted 001675.xml to YOLOv8 format!
# Converted 001682.xml to YOLOv8 format!
# Converted 001686.xml to YOLOv8 format!
# Converted 001687.xml to YOLOv8 format!
# Converted 001689.xml to YOLOv8 format!
# Converted 001693.xml to YOLOv8 format!
# Converted 001696.xml to YOLOv8 format!
# Converted 001697.xml to YOLOv8 format!
# Converted 001702.xml to YOLOv8 format!
# Converted 001707.xml to YOLOv8 format!
# Converted 001710.xml to YOLOv8 format!
# Converted 001711.xml to YOLOv8 format!
# Converted 001713.xml to YOLOv8 format!
# Converted 001725.xml to YOLOv8 format!
# Converted 001727.xml to YOLOv8 format!
# Converted 001729.xml to YOLOv8 format!
# Converted 001738.xml to YOLOv8 format!
# Converted 001739.xml to YOLOv8 format!
# Converted 001746.xml to YOLOv8 format!
# Converted 001747.xml to YOLOv8 format!
# Converted 001751.xml to YOLOv8 format!
# Converted 001752.xml to YOLOv8 format!
# Converted 001757.xml to YOLOv8 format!
# Converted 001758.xml to YOLOv8 format!
# Converted 001760.xml to YOLOv8 format!
# Converted 001773.xml to YOLOv8 format!
# Converted 001781.xml to YOLOv8 format!
# Converted 001788.xml to YOLOv8 format!
# Converted 001790.xml to YOLOv8 format!
# Converted 001792.xml to YOLOv8 format!
# Converted 001806.xml to YOLOv8 format!
# Converted 001807.xml to YOLOv8 format!
# Converted 001809.xml to YOLOv8 format!
# Converted 001810.xml to YOLOv8 format!
# Converted 001811.xml to YOLOv8 format!
# Converted 001812.xml to YOLOv8 format!
# Converted 001814.xml to YOLOv8 format!
# Converted 001824.xml to YOLOv8 format!
# Converted 001831.xml to YOLOv8 format!
# Converted 001834.xml to YOLOv8 format!
# Converted 001836.xml to YOLOv8 format!
# Converted 001837.xml to YOLOv8 format!
# Converted 001840.xml to YOLOv8 format!
# Converted 001841.xml to YOLOv8 format!
# Converted 001842.xml to YOLOv8 format!
# Converted 001843.xml to YOLOv8 format!
# Converted 001846.xml to YOLOv8 format!
# Converted 001852.xml to YOLOv8 format!
# Converted 001854.xml to YOLOv8 format!
# Converted 001855.xml to YOLOv8 format!
# Converted 001858.xml to YOLOv8 format!
# Converted 001865.xml to YOLOv8 format!
# Converted 001873.xml to YOLOv8 format!
# Converted 001875.xml to YOLOv8 format!
# Converted 001878.xml to YOLOv8 format!
# Converted 001883.xml to YOLOv8 format!
# Converted 001889.xml to YOLOv8 format!
# Converted 001890.xml to YOLOv8 format!
# Converted 001893.xml to YOLOv8 format!
# Converted 001898.xml to YOLOv8 format!
# Converted 001908.xml to YOLOv8 format!
# Converted 001910.xml to YOLOv8 format!
# Converted 001911.xml to YOLOv8 format!
# Converted 001913.xml to YOLOv8 format!
# Converted 001916.xml to YOLOv8 format!
# Converted 001921.xml to YOLOv8 format!
# Converted 001926.xml to YOLOv8 format!
# Converted 001930.xml to YOLOv8 format!
# Converted 001931.xml to YOLOv8 format!
# Converted 001932.xml to YOLOv8 format!
# Converted 001937.xml to YOLOv8 format!
# Converted 001939.xml to YOLOv8 format!
# Converted 001943.xml to YOLOv8 format!
# Converted 001948.xml to YOLOv8 format!
# Converted 001951.xml to YOLOv8 format!
# Converted 001952.xml to YOLOv8 format!
# Converted 001953.xml to YOLOv8 format!
# Converted 001961.xml to YOLOv8 format!
# Converted 001969.xml to YOLOv8 format!
# Converted 001971.xml to YOLOv8 format!
# Converted 001974.xml to YOLOv8 format!
# Converted 001987.xml to YOLOv8 format!
# Converted 001989.xml to YOLOv8 format!
# Converted 001990.xml to YOLOv8 format!
# Converted 001997.xml to YOLOv8 format!
# Converted 005000.xml to YOLOv8 format!
# Converted 005003.xml to YOLOv8 format!
# Converted 005009.xml to YOLOv8 format!
# Converted 005012.xml to YOLOv8 format!
# Converted 005013.xml to YOLOv8 format!
# Converted 005021.xml to YOLOv8 format!
# Converted 005026.xml to YOLOv8 format!
# Converted 005027.xml to YOLOv8 format!
# Converted 005028.xml to YOLOv8 format!
# Converted 005031.xml to YOLOv8 format!
# Converted 005038.xml to YOLOv8 format!
# Converted 005055.xml to YOLOv8 format!
# Converted 005057.xml to YOLOv8 format!
# Converted 005069.xml to YOLOv8 format!
# Converted 005071.xml to YOLOv8 format!
# Converted 005072.xml to YOLOv8 format!
# Converted 005081.xml to YOLOv8 format!
# Converted 005086.xml to YOLOv8 format!
# Converted 005087.xml to YOLOv8 format!
# Converted 005092.xml to YOLOv8 format!
# Converted 005097.xml to YOLOv8 format!
# Converted 005099.xml to YOLOv8 format!
# Converted 005106.xml to YOLOv8 format!
# Converted 005113.xml to YOLOv8 format!
# Converted 005114.xml to YOLOv8 format!
# Converted 005119.xml to YOLOv8 format!
# Converted 005126.xml to YOLOv8 format!
# Converted 005128.xml to YOLOv8 format!
# Converted 005129.xml to YOLOv8 format!
# Converted 005132.xml to YOLOv8 format!
# Converted 005138.xml to YOLOv8 format!
# Converted 005141.xml to YOLOv8 format!
# Converted 005145.xml to YOLOv8 format!
# Converted 005154.xml to YOLOv8 format!
# Converted 005155.xml to YOLOv8 format!
# Converted 005159.xml to YOLOv8 format!
# Converted 005164.xml to YOLOv8 format!
# Converted 005166.xml to YOLOv8 format!
# Converted 005175.xml to YOLOv8 format!
# Converted 005184.xml to YOLOv8 format!
# Converted 005188.xml to YOLOv8 format!
# Converted 005190.xml to YOLOv8 format!
# Converted 005197.xml to YOLOv8 format!
# Converted 005198.xml to YOLOv8 format!
# Converted 005200.xml to YOLOv8 format!
# Converted 005201.xml to YOLOv8 format!
# Converted 005207.xml to YOLOv8 format!
# Converted 005212.xml to YOLOv8 format!
# Converted 005216.xml to YOLOv8 format!
# Converted 005219.xml to YOLOv8 format!
# Converted 005222.xml to YOLOv8 format!
# Converted 005225.xml to YOLOv8 format!
# Converted 005228.xml to YOLOv8 format!
# Converted 005237.xml to YOLOv8 format!
# Converted 005240.xml to YOLOv8 format!
# Converted 005242.xml to YOLOv8 format!
# Converted 005244.xml to YOLOv8 format!
# Converted 005250.xml to YOLOv8 format!
# Converted 005260.xml to YOLOv8 format!
# Converted 005262.xml to YOLOv8 format!
# Converted 005268.xml to YOLOv8 format!
# Converted 005273.xml to YOLOv8 format!
# Converted 005275.xml to YOLOv8 format!
# Converted 005278.xml to YOLOv8 format!
# Converted 005280.xml to YOLOv8 format!
# Converted 005284.xml to YOLOv8 format!
# Converted 005289.xml to YOLOv8 format!
# Converted 00550_jpg.rf.956081908ad03e1ac7531cf1445c948a.xml to YOLOv8 format!
# Converted 00570_jpg.rf.8ef9857b5322e813de5cbd952d01b137.xml to YOLOv8 format!
# Converted 00617_jpg.rf.6c879ad11ecb4c30ed430299227b33d0.xml to YOLOv8 format!
# Converted 006276_jpg.rf.4da030f18de405fcd561b953c26f9383.xml to YOLOv8 format!
# Converted 006336_jpg.rf.4882fa277106be1378a906016ab8a711.xml to YOLOv8 format!
# Converted 006369_jpg.rf.5a962f5cea4ec0c8758fdca0b035728d.xml to YOLOv8 format!
# Converted 00977_jpg.rf.f95b8f2a8ddd0df6ee5f56d665ebbb55.xml to YOLOv8 format!
# Converted 01338_jpg.rf.e142346c853fbd92e2340e43eb30eecf.xml to YOLOv8 format!
# Converted 02092_jpg.rf.934d13f377f95d9adae1f393f427ba32.xml to YOLOv8 format!
# Converted 02567_jpg.rf.d1327d7fe3826f7ae0976fc5e90f94aa.xml to YOLOv8 format!
# Converted Aitin1170_jpg.rf.1b9fa28a4e61ee842a39db039d69d464.xml to YOLOv8 format!
# Converted Aitin3205_jpg.rf.0e0bc650138d83144f9e7196dd2bec38.xml to YOLOv8 format!
# Converted gettyimages-650169013-612x612_jpg.rf.90fc5c76e7c05968c9b793beb168af66.xml to YOLOv8 format!
# Converted helmet9991123_jpg.rf.b2f88448522c155ac91f0ab719addf38.xml to YOLOv8 format!
# Converted helmet999908_jpg.rf.eb7ec7dc0f18f138ae8ef798ce105624.xml to YOLOv8 format!
# Converted helmet999934_jpg.rf.7ac9be3c69da7e2d4edf14bf94abc29c.xml to YOLOv8 format!
# Converted helmet999958_jpg.rf.c20b516a6a36203afcd0cd426a11b71c.xml to YOLOv8 format!
# Converted helmet999965_jpg.rf.756eaab75a0b323e1784e0115c0a35e8.xml to YOLOv8 format!
# Converted images-2022-07-04T013042_jpg.rf.b978dadc52cedd1622e4ef2c8cd1489d.xml to YOLOv8 format!
# Converted images-2022-07-04T013101_jpg.rf.61a513fd8447097dc3c37ad8e6ab7e78.xml to YOLOv8 format!
# Converted images85_jpg.rf.63100ad7637913c912a58d3538cae4bd.xml to YOLOv8 format!
# Converted image_108_jpg.rf.6b8ca4832a9576fc6d610029fbaed93a.xml to YOLOv8 format!
# Converted image_108_jpg.rf.a2a7f9dd16e7a136d02fb42a810d1644.xml to YOLOv8 format!
# Converted image_123_jpg.rf.97f3e3dfff77ad0bdf3ed26cebb847c2.xml to YOLOv8 format!
# Converted image_146_jpg.rf.ffe871c6889f76ba6b6e19534dce0fb6.xml to YOLOv8 format!
# Converted image_150_jpg.rf.6b42024e9ab03c2c17d1025c76bff9a0.xml to YOLOv8 format!
# Converted image_154_jpg.rf.8b5af37534dcf73cb9cd2833f7630273.xml to YOLOv8 format!
# Converted image_158_jpg.rf.21b1c9f094c45914d813470b6a644c58.xml to YOLOv8 format!
# Converted image_159_jpg.rf.0483e0dd4df48c05815b5b0d751cbbc3.xml to YOLOv8 format!
# Converted image_166_jpg.rf.0c224aad30b67729bbd50121255b0e0c.xml to YOLOv8 format!
# Converted image_190_jpg.rf.2e92814af735dd1c2f54325bac2750f3.xml to YOLOv8 format!
# Converted image_217_jpg.rf.1e4d9fbf97a087648742078ff5941b67.xml to YOLOv8 format!
# Converted image_217_jpg.rf.460f83c2cb3f8a18689f92b2f8835f9a.xml to YOLOv8 format!
# Converted image_227_jpg.rf.0f48674aea1b8aaf3e7baac80abf9ea4.xml to YOLOv8 format!
# Converted image_237_jpg.rf.353ad34ef2718e9f9e14f8a21bc5afa6.xml to YOLOv8 format!
# Converted ppe_0153_jpg.rf.cfc5bb75e388eecc7b459d59d4c41b95.xml to YOLOv8 format!
# Converted ppe_0886_jpg.rf.ad5ddd17cb1d27b716f5681b4aae8fd3.xml to YOLOv8 format!
# Converted ppe_0941_jpg.rf.c7fcf7d8f89d423c80586709b693b697.xml to YOLOv8 format!
# Converted ppe_1022_jpg.rf.589fdbf689e5614020d4706c7a5f5083.xml to YOLOv8 format!
# Converted ppe_1130_jpg.rf.88358e5b86cdc4d55d4689abe5cb87e4.xml to YOLOv8 format!
# Converted ppe_1166_jpg.rf.ccad8bba387168ec13aa4f3ce7848f27.xml to YOLOv8 format!
# Converted ppe_1189_jpg.rf.f6977c81a4c10b70e7d36a5b90956b94.xml to YOLOv8 format!
# Converted ppe_1202_jpg.rf.c2963de6cf48426e058b866f008b72f0.xml to YOLOv8 format!
# Converted RPReplay_Final1667001201_MP4-459_jpg.rf.352ca04a4c2cc5df8bf2dd3d8c01c120.xml to YOLOv8 format!
# Converted TsirinTu0018_jpg.rf.3fe2fc0fdb3a31434f1bac91d61e53be.xml to YOLOv8 format!
# Converted Video1_2_jpg.rf.0754a5fb79396bd903a4ded0145f7bc9.xml to YOLOv8 format!
# Converted Video2_143_jpg.rf.7035ecddb4b2c8cfdbd5a004d946a496.xml to YOLOv8 format!
# Converted Video2_150_jpg.rf.b9afc4a41d95211f77fb12a37629e211.xml to YOLOv8 format!
# Converted Video2_174_jpg.rf.d04a29e17bdf3c1135e2a0d6744250c0.xml to YOLOv8 format!
# Converted Video2_178_jpg.rf.589896c6e0322de89e52bcd29313c422.xml to YOLOv8 format!
# Converted Video2_38_jpg.rf.a593c2439bc2acd57f3d9e911c710e75.xml to YOLOv8 format!
# Converted Video2_42_jpg.rf.f8ab7627f1a6ff7bcb89500ce01f949a.xml to YOLOv8 format!
# Converted Video2_83_jpg.rf.3f002b5fe1217bb7937e1ac3eb8488ae.xml to YOLOv8 format!
# Converted Video2_91_jpg.rf.faca99c76175b53a646f60aa1abc4b14.xml to YOLOv8 format!
# Converted Video3_19_jpg.rf.ae0c1d1923ab81af7575d5d532490729.xml to YOLOv8 format!
# Converted Video3_234_jpg.rf.471c24f2553d586d17a85abce416276b.xml to YOLOv8 format!
# Converted Video3_42_jpg.rf.38bac29f7f62c6a04896444e6e26a925.xml to YOLOv8 format!
# Converted youtube-6_jpg.rf.a9f31f242ee7d731c625ed07f6002b9b.xml to YOLOv8 format!
# Converted YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-31_jpg.rf.c88b23a01eb99ef16b5208d11dd5764f.xml to YOLOv8 format!
# Converted YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-7_jpg.rf.3ad1e4933e697179f9d54d06d31830e4.xml to YOLOv8 format!
# Converted YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC-hj-Zo-720p_mp4-7_jpg.rf.4d6b125dc1fa9f9970e29a35bab61c9a.xml to YOLOv8 format!
# Converted YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-34_jpg.rf.01d6349eabce5613415c586a543c9f0b.xml to YOLOv8 format!
# Converted YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-35_jpg.rf.d03a2efbca9287a52d02a3d428d2aaf5.xml to YOLOv8 format!
# Finished converting Pascal VOC XML annotations!

# %%
import os

def move_labels(image_dir, label_dir):
  """
  Moves all label files (TXT format) from the image directory to a separate label directory.

  Args:
    image_dir: Path to the directory containing images and label files.
    label_dir: Path to the destination directory for label files.
  """

  # Create the label directory if it doesn't exist
  if not os.path.exists(label_dir):
    os.makedirs(label_dir)

  # Loop through files in the image directory
  for filename in os.listdir(image_dir):
    if filename.endswith(".txt"):  # Check for label files (TXT format)
      label_path = os.path.join(image_dir, filename)
      new_label_path = os.path.join(label_dir, filename)

      # Move the label file
      os.rename(label_path, new_label_path)
      print(f"Moved label file: {filename}")

# Define directories
image_dir = "C:\\Users\\hp\\Desktop\\machine-test\\datasets\\images"  # Replace with your directory
label_dir = "C:\\Users\\hp\\Desktop\\machine-test\\datasets\lablels_new"  # Replace with your desired label directory

# Move the label files
move_labels(image_dir, label_dir)

print("Finished moving label files!")
# Out:
# Moved label file: -1477-_png_jpg.rf.bac8d06edca64da17ced23797d0e2339.txt
# Moved label file: -1532-_png_jpg.rf.08a5b6985f24bfe7efefdb45c04469c2.txt
# Moved label file: -1571-_png_jpg.rf.ccf919d5ea025ddc24cf0a707b331249.txt
# Moved label file: -1579-_png_jpg.rf.c8f91ec3791bf03ccf9eca6c29f62aec.txt
# Moved label file: -1597-_png_jpg.rf.3bd5df66feaa51e0d65197b4acaf356f.txt
# Moved label file: -1817-_png_jpg.rf.0c0c9d7ee4b875c6ad49937fc72182f6.txt
# Moved label file: -1832-_png_jpg.rf.d56cb4edba4c059bdfa7f2c581d26a19.txt
# Moved label file: -184-_png_jpg.rf.b02963998a79b9ad5079f57b65130bc2.txt
# Moved label file: -1943-_png_jpg.rf.fe8693f39c8d2c4be6615a63edd3550d.txt
# Moved label file: -2082-_png_jpg.rf.7b89e77b67643cd28c0ce52ed7e588e3.txt
# Moved label file: -2091-_png_jpg.rf.24a38225fa17a89f450e6fcf90584bb5.txt
# Moved label file: -2168-_png_jpg.rf.cd5ce7cad7216bda1d5a2e90d9ccdd4e.txt
# Moved label file: -2180-_png_jpg.rf.9d63bb305e7747d22fe9a196dcc5ce13.txt
# Moved label file: -2293-_png_jpg.rf.b1d581d625ae74bb60b5d56e7b562654.txt
# Moved label file: -2338-_png_jpg.rf.e79ac380146af51e53738fd6184e1808.txt
# Moved label file: -2390-_png_jpg.rf.fa4cf091a0bc051c044e2505719d3971.txt
# Moved label file: -2391-_png_jpg.rf.8781d03c5c7efeeb7fdaeb65e1dd0fc7.txt
# Moved label file: -2398-_png_jpg.rf.bcec23ae95199cde62866097de49e92c.txt
# Moved label file: -2435-_png_jpg.rf.d88968da6353df51746244bb3619cc5a.txt
# Moved label file: -4100-_png_jpg.rf.aebfe87c2b4f556f03d14fc3cc6facf7.txt
# Moved label file: -4216-_png_jpg.rf.881e17f72716e3cbdaa9d20cf9558142.txt
# Moved label file: -4379-_png_jpg.rf.03c410bbf91f791a4bade1f8673fa79c.txt
# Moved label file: 001003.txt
# Moved label file: 001005.txt
# Moved label file: 001029.txt
# Moved label file: 001037.txt
# Moved label file: 001038.txt
# Moved label file: 001042.txt
# Moved label file: 001045.txt
# Moved label file: 001054.txt
# Moved label file: 001056_jpg.rf.fb5d9fbc2ccfa43ca89d84be6d2a98ea.txt
# Moved label file: 001059.txt
# Moved label file: 001060.txt
# Moved label file: 001062.txt
# Moved label file: 001071.txt
# Moved label file: 001073.txt
# Moved label file: 001080.txt
# Moved label file: 001082.txt
# Moved label file: 001083.txt
# Moved label file: 001085.txt
# Moved label file: 001086.txt
# Moved label file: 001092.txt
# Moved label file: 001093.txt
# Moved label file: 001096.txt
# Moved label file: 001107_jpg.rf.ddc4b21edf46aaa9518dfe33a381ff29.txt
# Moved label file: 001109.txt
# Moved label file: 001111.txt
# Moved label file: 001124.txt
# Moved label file: 001129.txt
# Moved label file: 001142.txt
# Moved label file: 001143.txt
# Moved label file: 001146.txt
# Moved label file: 001147.txt
# Moved label file: 001152.txt
# Moved label file: 001155.txt
# Moved label file: 001157.txt
# Moved label file: 001158.txt
# Moved label file: 001164.txt
# Moved label file: 001173.txt
# Moved label file: 001175.txt
# Moved label file: 001177.txt
# Moved label file: 001179.txt
# Moved label file: 001180.txt
# Moved label file: 001183.txt
# Moved label file: 001184.txt
# Moved label file: 001185.txt
# Moved label file: 001186.txt
# Moved label file: 001187.txt
# Moved label file: 001188.txt
# Moved label file: 001190.txt
# Moved label file: 001191.txt
# Moved label file: 001196.txt
# Moved label file: 001198.txt
# Moved label file: 001199.txt
# Moved label file: 001201.txt
# Moved label file: 001202.txt
# Moved label file: 001205.txt
# Moved label file: 001209.txt
# Moved label file: 001213.txt
# Moved label file: 001214_jpg.rf.1341753c952df6e0889b1f781af22c77.txt
# Moved label file: 001216_jpg.rf.c7de195db643cb4d72f58f262b39b050.txt
# Moved label file: 001221.txt
# Moved label file: 001222.txt
# Moved label file: 001223.txt
# Moved label file: 001224.txt
# Moved label file: 001225.txt
# Moved label file: 001229.txt
# Moved label file: 001231.txt
# Moved label file: 001232.txt
# Moved label file: 001236.txt
# Moved label file: 001242.txt
# Moved label file: 001246_jpg.rf.05724a1c67f05c4fbd6fb3d872bc98b4.txt
# Moved label file: 001250.txt
# Moved label file: 001257.txt
# Moved label file: 001265.txt
# Moved label file: 001268.txt
# Moved label file: 001271.txt
# Moved label file: 001280.txt
# Moved label file: 001282.txt
# Moved label file: 001284.txt
# Moved label file: 001291.txt
# Moved label file: 001295.txt
# Moved label file: 001297.txt
# Moved label file: 001302.txt
# Moved label file: 001302_jpg.rf.6e51fb4e9255ceda9bca16f35d4ae32b.txt
# Moved label file: 001303.txt
# Moved label file: 001305.txt
# Moved label file: 001308.txt
# Moved label file: 001318.txt
# Moved label file: 001320.txt
# Moved label file: 001321.txt
# Moved label file: 001323.txt
# Moved label file: 001324.txt
# Moved label file: 001325.txt
# Moved label file: 001326.txt
# Moved label file: 001330.txt
# Moved label file: 001331.txt
# Moved label file: 001332.txt
# Moved label file: 001333_jpg.rf.25550b8186ab6e741765efbb21e9e59e.txt
# Moved label file: 001338.txt
# Moved label file: 001339.txt
# Moved label file: 001341.txt
# Moved label file: 001344_jpg.rf.1c7c5ed37e407155e2d7cf0216f893ed.txt
# Moved label file: 001345.txt
# Moved label file: 001347.txt
# Moved label file: 001353_jpg.rf.c0abf8e966961dd3c902dce35a401240.txt
# Moved label file: 001358.txt
# Moved label file: 001360.txt
# Moved label file: 001363.txt
# Moved label file: 001365.txt
# Moved label file: 001367.txt
# Moved label file: 001373.txt
# Moved label file: 001376.txt
# Moved label file: 001381.txt
# Moved label file: 001388.txt
# Moved label file: 001391.txt
# Moved label file: 001392.txt
# Moved label file: 001393.txt
# Moved label file: 001395.txt
# Moved label file: 001397.txt
# Moved label file: 001406.txt
# Moved label file: 001411.txt
# Moved label file: 001412.txt
# Moved label file: 001417.txt
# Moved label file: 001418.txt
# Moved label file: 001426.txt
# Moved label file: 001436.txt
# Moved label file: 001438.txt
# Moved label file: 001442.txt
# Moved label file: 001448.txt
# Moved label file: 001451.txt
# Moved label file: 001453.txt
# Moved label file: 001454.txt
# Moved label file: 001455.txt
# Moved label file: 001474.txt
# Moved label file: 001476.txt
# Moved label file: 001479.txt
# Moved label file: 001486.txt
# Moved label file: 001487.txt
# Moved label file: 001501.txt
# Moved label file: 001502.txt
# Moved label file: 001503.txt
# Moved label file: 001509.txt
# Moved label file: 001514.txt
# Moved label file: 001516.txt
# Moved label file: 001531.txt
# Moved label file: 001532.txt
# Moved label file: 001535.txt
# Moved label file: 001541.txt
# Moved label file: 001544.txt
# Moved label file: 001545.txt
# Moved label file: 001546.txt
# Moved label file: 001547.txt
# Moved label file: 001551.txt
# Moved label file: 001553.txt
# Moved label file: 001561.txt
# Moved label file: 001568.txt
# Moved label file: 001580.txt
# Moved label file: 001589.txt
# Moved label file: 001597.txt
# Moved label file: 001604.txt
# Moved label file: 001611.txt
# Moved label file: 001618.txt
# Moved label file: 001619.txt
# Moved label file: 001624.txt
# Moved label file: 001627.txt
# Moved label file: 001628.txt
# Moved label file: 001631.txt
# Moved label file: 001634.txt
# Moved label file: 001637.txt
# Moved label file: 001642.txt
# Moved label file: 001645.txt
# Moved label file: 001646.txt
# Moved label file: 001647.txt
# Moved label file: 001649.txt
# Moved label file: 001657.txt
# Moved label file: 001659.txt
# Moved label file: 001661.txt
# Moved label file: 001664.txt
# Moved label file: 001668.txt
# Moved label file: 001669.txt
# Moved label file: 001675.txt
# Moved label file: 001682.txt
# Moved label file: 001686.txt
# Moved label file: 001687.txt
# Moved label file: 001689.txt
# Moved label file: 001693.txt
# Moved label file: 001696.txt
# Moved label file: 001697.txt
# Moved label file: 001702.txt
# Moved label file: 001707.txt
# Moved label file: 001710.txt
# Moved label file: 001711.txt
# Moved label file: 001713.txt
# Moved label file: 001725.txt
# Moved label file: 001727.txt
# Moved label file: 001729.txt
# Moved label file: 001738.txt
# Moved label file: 001739.txt
# Moved label file: 001746.txt
# Moved label file: 001747.txt
# Moved label file: 001751.txt
# Moved label file: 001752.txt
# Moved label file: 001757.txt
# Moved label file: 001758.txt
# Moved label file: 001760.txt
# Moved label file: 001773.txt
# Moved label file: 001781.txt
# Moved label file: 001788.txt
# Moved label file: 001790.txt
# Moved label file: 001792.txt
# Moved label file: 001806.txt
# Moved label file: 001807.txt
# Moved label file: 001809.txt
# Moved label file: 001810.txt
# Moved label file: 001811.txt
# Moved label file: 001812.txt
# Moved label file: 001814.txt
# Moved label file: 001824.txt
# Moved label file: 001831.txt
# Moved label file: 001834.txt
# Moved label file: 001836.txt
# Moved label file: 001837.txt
# Moved label file: 001840.txt
# Moved label file: 001841.txt
# Moved label file: 001842.txt
# Moved label file: 001843.txt
# Moved label file: 001846.txt
# Moved label file: 001852.txt
# Moved label file: 001854.txt
# Moved label file: 001855.txt
# Moved label file: 001858.txt
# Moved label file: 001865.txt
# Moved label file: 001873.txt
# Moved label file: 001875.txt
# Moved label file: 001878.txt
# Moved label file: 001883.txt
# Moved label file: 001889.txt
# Moved label file: 001890.txt
# Moved label file: 001893.txt
# Moved label file: 001898.txt
# Moved label file: 001908.txt
# Moved label file: 001910.txt
# Moved label file: 001911.txt
# Moved label file: 001913.txt
# Moved label file: 001916.txt
# Moved label file: 001921.txt
# Moved label file: 001926.txt
# Moved label file: 001930.txt
# Moved label file: 001931.txt
# Moved label file: 001932.txt
# Moved label file: 001937.txt
# Moved label file: 001939.txt
# Moved label file: 001943.txt
# Moved label file: 001948.txt
# Moved label file: 001951.txt
# Moved label file: 001952.txt
# Moved label file: 001953.txt
# Moved label file: 001961.txt
# Moved label file: 001969.txt
# Moved label file: 001971.txt
# Moved label file: 001974.txt
# Moved label file: 001987.txt
# Moved label file: 001989.txt
# Moved label file: 001990.txt
# Moved label file: 001997.txt
# Moved label file: 005000.txt
# Moved label file: 005003.txt
# Moved label file: 005009.txt
# Moved label file: 005012.txt
# Moved label file: 005013.txt
# Moved label file: 005021.txt
# Moved label file: 005026.txt
# Moved label file: 005027.txt
# Moved label file: 005028.txt
# Moved label file: 005031.txt
# Moved label file: 005038.txt
# Moved label file: 005055.txt
# Moved label file: 005057.txt
# Moved label file: 005069.txt
# Moved label file: 005071.txt
# Moved label file: 005072.txt
# Moved label file: 005081.txt
# Moved label file: 005086.txt
# Moved label file: 005087.txt
# Moved label file: 005092.txt
# Moved label file: 005097.txt
# Moved label file: 005099.txt
# Moved label file: 005106.txt
# Moved label file: 005113.txt
# Moved label file: 005114.txt
# Moved label file: 005119.txt
# Moved label file: 005126.txt
# Moved label file: 005128.txt
# Moved label file: 005129.txt
# Moved label file: 005132.txt
# Moved label file: 005138.txt
# Moved label file: 005141.txt
# Moved label file: 005145.txt
# Moved label file: 005154.txt
# Moved label file: 005155.txt
# Moved label file: 005159.txt
# Moved label file: 005164.txt
# Moved label file: 005166.txt
# Moved label file: 005175.txt
# Moved label file: 005184.txt
# Moved label file: 005188.txt
# Moved label file: 005190.txt
# Moved label file: 005197.txt
# Moved label file: 005198.txt
# Moved label file: 005200.txt
# Moved label file: 005201.txt
# Moved label file: 005207.txt
# Moved label file: 005212.txt
# Moved label file: 005216.txt
# Moved label file: 005219.txt
# Moved label file: 005222.txt
# Moved label file: 005225.txt
# Moved label file: 005228.txt
# Moved label file: 005237.txt
# Moved label file: 005240.txt
# Moved label file: 005242.txt
# Moved label file: 005244.txt
# Moved label file: 005250.txt
# Moved label file: 005260.txt
# Moved label file: 005262.txt
# Moved label file: 005268.txt
# Moved label file: 005273.txt
# Moved label file: 005275.txt
# Moved label file: 005278.txt
# Moved label file: 005280.txt
# Moved label file: 005284.txt
# Moved label file: 005289.txt
# Moved label file: 00550_jpg.rf.956081908ad03e1ac7531cf1445c948a.txt
# Moved label file: 00570_jpg.rf.8ef9857b5322e813de5cbd952d01b137.txt
# Moved label file: 00617_jpg.rf.6c879ad11ecb4c30ed430299227b33d0.txt
# Moved label file: 006276_jpg.rf.4da030f18de405fcd561b953c26f9383.txt
# Moved label file: 006336_jpg.rf.4882fa277106be1378a906016ab8a711.txt
# Moved label file: 006369_jpg.rf.5a962f5cea4ec0c8758fdca0b035728d.txt
# Moved label file: 00977_jpg.rf.f95b8f2a8ddd0df6ee5f56d665ebbb55.txt
# Moved label file: 01338_jpg.rf.e142346c853fbd92e2340e43eb30eecf.txt
# Moved label file: 02092_jpg.rf.934d13f377f95d9adae1f393f427ba32.txt
# Moved label file: 02567_jpg.rf.d1327d7fe3826f7ae0976fc5e90f94aa.txt
# Moved label file: Aitin1170_jpg.rf.1b9fa28a4e61ee842a39db039d69d464.txt
# Moved label file: Aitin3205_jpg.rf.0e0bc650138d83144f9e7196dd2bec38.txt
# Moved label file: gettyimages-650169013-612x612_jpg.rf.90fc5c76e7c05968c9b793beb168af66.txt
# Moved label file: helmet9991123_jpg.rf.b2f88448522c155ac91f0ab719addf38.txt
# Moved label file: helmet999908_jpg.rf.eb7ec7dc0f18f138ae8ef798ce105624.txt
# Moved label file: helmet999934_jpg.rf.7ac9be3c69da7e2d4edf14bf94abc29c.txt
# Moved label file: helmet999958_jpg.rf.c20b516a6a36203afcd0cd426a11b71c.txt
# Moved label file: helmet999965_jpg.rf.756eaab75a0b323e1784e0115c0a35e8.txt
# Moved label file: images-2022-07-04T013042_jpg.rf.b978dadc52cedd1622e4ef2c8cd1489d.txt
# Moved label file: images-2022-07-04T013101_jpg.rf.61a513fd8447097dc3c37ad8e6ab7e78.txt
# Moved label file: images85_jpg.rf.63100ad7637913c912a58d3538cae4bd.txt
# Moved label file: image_108_jpg.rf.6b8ca4832a9576fc6d610029fbaed93a.txt
# Moved label file: image_108_jpg.rf.a2a7f9dd16e7a136d02fb42a810d1644.txt
# Moved label file: image_123_jpg.rf.97f3e3dfff77ad0bdf3ed26cebb847c2.txt
# Moved label file: image_146_jpg.rf.ffe871c6889f76ba6b6e19534dce0fb6.txt
# Moved label file: image_150_jpg.rf.6b42024e9ab03c2c17d1025c76bff9a0.txt
# Moved label file: image_154_jpg.rf.8b5af37534dcf73cb9cd2833f7630273.txt
# Moved label file: image_158_jpg.rf.21b1c9f094c45914d813470b6a644c58.txt
# Moved label file: image_159_jpg.rf.0483e0dd4df48c05815b5b0d751cbbc3.txt
# Moved label file: image_166_jpg.rf.0c224aad30b67729bbd50121255b0e0c.txt
# Moved label file: image_190_jpg.rf.2e92814af735dd1c2f54325bac2750f3.txt
# Moved label file: image_217_jpg.rf.1e4d9fbf97a087648742078ff5941b67.txt
# Moved label file: image_217_jpg.rf.460f83c2cb3f8a18689f92b2f8835f9a.txt
# Moved label file: image_227_jpg.rf.0f48674aea1b8aaf3e7baac80abf9ea4.txt
# Moved label file: image_237_jpg.rf.353ad34ef2718e9f9e14f8a21bc5afa6.txt
# Moved label file: ppe_0153_jpg.rf.cfc5bb75e388eecc7b459d59d4c41b95.txt
# Moved label file: ppe_0886_jpg.rf.ad5ddd17cb1d27b716f5681b4aae8fd3.txt
# Moved label file: ppe_0941_jpg.rf.c7fcf7d8f89d423c80586709b693b697.txt
# Moved label file: ppe_1022_jpg.rf.589fdbf689e5614020d4706c7a5f5083.txt
# Moved label file: ppe_1130_jpg.rf.88358e5b86cdc4d55d4689abe5cb87e4.txt
# Moved label file: ppe_1166_jpg.rf.ccad8bba387168ec13aa4f3ce7848f27.txt
# Moved label file: ppe_1189_jpg.rf.f6977c81a4c10b70e7d36a5b90956b94.txt
# Moved label file: ppe_1202_jpg.rf.c2963de6cf48426e058b866f008b72f0.txt
# Moved label file: RPReplay_Final1667001201_MP4-459_jpg.rf.352ca04a4c2cc5df8bf2dd3d8c01c120.txt
# Moved label file: TsirinTu0018_jpg.rf.3fe2fc0fdb3a31434f1bac91d61e53be.txt
# Moved label file: Video1_2_jpg.rf.0754a5fb79396bd903a4ded0145f7bc9.txt
# Moved label file: Video2_143_jpg.rf.7035ecddb4b2c8cfdbd5a004d946a496.txt
# Moved label file: Video2_150_jpg.rf.b9afc4a41d95211f77fb12a37629e211.txt
# Moved label file: Video2_174_jpg.rf.d04a29e17bdf3c1135e2a0d6744250c0.txt
# Moved label file: Video2_178_jpg.rf.589896c6e0322de89e52bcd29313c422.txt
# Moved label file: Video2_38_jpg.rf.a593c2439bc2acd57f3d9e911c710e75.txt
# Moved label file: Video2_42_jpg.rf.f8ab7627f1a6ff7bcb89500ce01f949a.txt
# Moved label file: Video2_83_jpg.rf.3f002b5fe1217bb7937e1ac3eb8488ae.txt
# Moved label file: Video2_91_jpg.rf.faca99c76175b53a646f60aa1abc4b14.txt
# Moved label file: Video3_19_jpg.rf.ae0c1d1923ab81af7575d5d532490729.txt
# Moved label file: Video3_234_jpg.rf.471c24f2553d586d17a85abce416276b.txt
# Moved label file: Video3_42_jpg.rf.38bac29f7f62c6a04896444e6e26a925.txt
# Moved label file: youtube-6_jpg.rf.a9f31f242ee7d731c625ed07f6002b9b.txt
# Moved label file: YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-31_jpg.rf.c88b23a01eb99ef16b5208d11dd5764f.txt
# Moved label file: YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-7_jpg.rf.3ad1e4933e697179f9d54d06d31830e4.txt
# Moved label file: YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC-hj-Zo-720p_mp4-7_jpg.rf.4d6b125dc1fa9f9970e29a35bab61c9a.txt
# Moved label file: YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-34_jpg.rf.01d6349eabce5613415c586a543c9f0b.txt
# Moved label file: YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-35_jpg.rf.d03a2efbca9287a52d02a3d428d2aaf5.txt
# Finished moving label files!
